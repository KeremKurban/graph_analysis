# %%
import numpy as np
from scipy import sparse
import os
import scipy
import matplotlib.pyplot as plt

# %%
circuit_path = '/gpfs/bbp.cscs.ch/project/proj112/circuits/CA1/20211110-BioM/CircuitConfig'
cur_path = os.getcwd()

target='cylinder300'
cylinder_adj_file = f'cylinders_analysis/{target}/data/connectivity.npz'
slice_adj_file = ''

# %%
#circ=bluepy.Circuit(circuit_path)
data_dict = {}

cur_conn_path = os.path.join(cur_path,f'cylinders_analysis/{target}/data/connectivity.npz')
data_dict[target] = scipy.sparse.load_npz(cur_conn_path)
sparse_matrix = data_dict[target]

# %%
sparse_matrix
# Out:
# <6213x6213 sparse matrix of type '<class 'numpy.bool_'>'
# 	with 1236142 stored elements in Compressed Sparse Column format>

# %%
plt.spy(sparse_matrix,markersize=0.01)
