# %% [markdown]
# # Replicate Fig7D from Rees et al 2016

# %%
from igraph import *
from bluepy.enums import Cell
from scipy import sparse
import bluepy
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import logging
from graph_analysis.triplets import MotifReader, CA1MotifCalculator

# %%
all_motifs = ['-C','-B','-A','A','B','C','D','E','F','G','H','I','J','K','L','M']
save_dir = '../../output/triplets'
target = 'cylinder300'

# %% [markdown]
# # CA1 PYR:INT

# %%
check_mtypes = ['SP_PC','SP_PC','SP_PC']
compare_to = ['INT','INT','INT']


target_motifs_exc = {}
target_motifs_inh = {}

for motif_name in all_motifs:
    logging.info(f"Running motif calculation for {target} of motif {motif_name} of {check_mtypes}...")
    motif_reader = MotifReader()
    CM = motif_reader.name_to_matrix(motif_name)
    # logging.info(f"Motif matrix:\n{CM}")
    calculator = CA1MotifCalculator(target,check_mtypes, CM)
    num_motifs = calculator.count_motifs()  # proj samples not used for local computations

    logging.info(f"Running motif calculation for {target} of motif {motif_name} of {compare_to}...")

    calculator2 = CA1MotifCalculator(target,compare_to, CM)
    num_motifs2 = calculator2.count_motifs()  # proj samples not used for local computations

    target_motifs_exc[motif_name] = num_motifs
    target_motifs_inh[motif_name] = num_motifs2
# Out:
# INFO:root:Running motif calculation for cylinder300 of motif -C of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (-C) within the given adj matrix: 152000126800
# INFO:root:Running motif calculation for cylinder300 of motif -C of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (-C) within the given adj matrix: 116285837
# INFO:root:Running motif calculation for cylinder300 of motif -B of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (-B) within the given adj matrix: 3825310775
# INFO:root:Running motif calculation for cylinder300 of motif -B of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (-B) within the given adj matrix: 85864765
# INFO:root:Running motif calculation for cylinder300 of motif -A of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (-A) within the given adj matrix: 106890588
# INFO:root:Running motif calculation for cylinder300 of motif -A of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (-A) within the given adj matrix: 457187702
# INFO:root:Running motif calculation for cylinder300 of motif A of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (A) within the given adj matrix: 126008115
# INFO:root:Running motif calculation for cylinder300 of motif A of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (A) within the given adj matrix: 61513295
# INFO:root:Running motif calculation for cylinder300 of motif B of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (-A) within the given adj matrix: 82129746
# INFO:root:Running motif calculation for cylinder300 of motif B of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (-A) within the given adj matrix: 42307099
# INFO:root:Running motif calculation for cylinder300 of motif C of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (C) within the given adj matrix: 12915601
# INFO:root:Running motif calculation for cylinder300 of motif C of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (C) within the given adj matrix: 119997683
# INFO:root:Running motif calculation for cylinder300 of motif D of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (D) within the given adj matrix: 3356647
# INFO:root:Running motif calculation for cylinder300 of motif D of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (D) within the given adj matrix: 196327628
# INFO:root:Running motif calculation for cylinder300 of motif E of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (E) within the given adj matrix: 12915601
# INFO:root:Running motif calculation for cylinder300 of motif E of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (E) within the given adj matrix: 119997683
# INFO:root:Running motif calculation for cylinder300 of motif F of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (F) within the given adj matrix: 8480738
# INFO:root:Running motif calculation for cylinder300 of motif F of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (F) within the given adj matrix: 252163687
# INFO:root:Running motif calculation for cylinder300 of motif G of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (G) within the given adj matrix: 1245414
# INFO:root:Running motif calculation for cylinder300 of motif G of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (G) within the given adj matrix: 27679554
# INFO:root:Running motif calculation for cylinder300 of motif H of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (H) within the given adj matrix: 684604
# INFO:root:Running motif calculation for cylinder300 of motif H of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (H) within the given adj matrix: 898506638
# INFO:root:Running motif calculation for cylinder300 of motif I of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (I) within the given adj matrix: 1115834
# INFO:root:Running motif calculation for cylinder300 of motif I of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (I) within the given adj matrix: 838280482
# INFO:root:Running motif calculation for cylinder300 of motif J of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (J) within the given adj matrix: 455368
# INFO:root:Running motif calculation for cylinder300 of motif J of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (J) within the given adj matrix: 350256986
# INFO:root:Running motif calculation for cylinder300 of motif K of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (K) within the given adj matrix: 1247718
# INFO:root:Running motif calculation for cylinder300 of motif K of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (K) within the given adj matrix: 1102466548
# INFO:root:Running motif calculation for cylinder300 of motif L of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (L) within the given adj matrix: 98981
# INFO:root:Running motif calculation for cylinder300 of motif L of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (L) within the given adj matrix: 5752019591
# INFO:root:Running motif calculation for cylinder300 of motif M of ['SP_PC', 'SP_PC', 'SP_PC']...
# INFO:root:Total instances of given motif (M) within the given adj matrix: 25332
# INFO:root:Running motif calculation for cylinder300 of motif M of ['INT', 'INT', 'INT']...
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:st_index: 5536, end_index: 6213
# INFO:root:Total instances of given motif (M) within the given adj matrix: 122003519226

# %%
df1 = pd.DataFrame.from_dict(target_motifs_exc, orient='index',columns=[f'{target}_EXC'])
df2 = pd.DataFrame.from_dict(target_motifs_inh, orient='index',columns=[f'{target}_INH'])

df_ei = pd.concat([df1,df2],axis=1)

# %%
df_ei['ratio'] = df_ei[f'{target}_EXC']/df_ei[f'{target}_INH']

# %%
from bluepysnap import Circuit
c =Circuit('/gpfs/bbp.cscs.ch/project/proj112/circuits/CA1/20211110-BioM/sonata/circuit_config.json')
nodes = c.nodes['hippocampus_neurons']
target_nodes = nodes.get(target)

# count how many morph_class is INT
num_int = target_nodes[target_nodes['morph_class']=='INT'].shape[0]
num_exc = target_nodes[target_nodes['morph_class']=='PYR'].shape[0]
print(f"Number of INT cells: {num_int}")
print(f"Number of EXC cells: {num_exc}")
# Out:
# Number of INT cells: 677
# Number of EXC cells: 5536

# %%
def max_possible_triplet(num_cells):
    return num_cells*(num_cells-1)*(num_cells-2)/6

# %%
#normalize exc and inh values with max possible values
df_ei['ratio_norm'] = df_ei['ratio'] * (max_possible_triplet(num_int) / max_possible_triplet(num_exc))

# %%
df_ei.to_csv(f'{save_dir}/{target}_triplet_ratios_EI.csv')

# %%
chosen_df = df_ei.ratio[3:]
chosen_df.plot(figsize=(10,5),title=f'{target} motif ratio')
# plot all xticklabels
plt.xticks(np.arange(len(df_ei)-3), df_ei.index[3:])
# horizontal line at y=1
plt.axhline(y=1, color='r', linestyle='-')
plt.ylabel('Normalized Ratio')
plt.savefig(f'{save_dir}/{target}_triplet_ratios_EI.png',dpi=300)
plt.show()

chosen_df.plot(figsize=(10,5),title=f'{target} motif ratio')
# plot all xticklabels
plt.xticks(np.arange(len(df_ei)-3), df_ei.index[3:])
# horizontal line at y=1
plt.yscale('log')
plt.axhline(y=1, color='r', linestyle='-')
plt.ylabel('Normalized Ratio')
plt.savefig(f'{save_dir}/{target}_triplet_ratios_EI_log.png',dpi=300)
plt.show()

# %%
chosen_df = df_ei.ratio_norm[3:]
chosen_df.plot(figsize=(10,5),title=f'{target} motif ratio')
# plot all xticklabels
plt.xticks(np.arange(len(df_ei)-3), df_ei.index[3:])
# horizontal line at y=1
plt.axhline(y=1, color='r', linestyle='-')
plt.ylabel('Normalized Ratio')
plt.show()
plt.savefig(f'{save_dir}/{target}_motif_ratio_EI.png')

chosen_df.plot(figsize=(10,5),title=f'{target} motif ratio')
# plot all xticklabels
plt.xticks(np.arange(len(df_ei)-3), df_ei.index[3:])
# horizontal line at y=1
plt.yscale('log')
plt.axhline(y=1, color='r', linestyle='-')
plt.ylabel('Normalized Ratio')
plt.show()

# %% [markdown]
# # CA1 Perisomatic INT: Distal INT

# %%
check_mtypes = ['PeriSomatic_INH','PeriSomatic_INH','PeriSomatic_INH']
compare_to = ['Distal_INH','Distal_INH','Distal_INH']

target_motifs_perisomatic = {}
target_motifs_distal = {}

for motif_name in tqdm(all_motifs):
    logging.info(f"Running motif calculation for {target} of motif {motif_name} of {check_mtypes}...")
    motif_reader = MotifReader()
    CM = motif_reader.name_to_matrix(motif_name)
    # logging.info(f"Motif matrix:\n{CM}")
    calculator = CA1MotifCalculator(target,check_mtypes, CM)
    num_motifs = calculator.count_motifs()  # proj samples not used for local computations

    logging.info(f"Running motif calculation for {target} of motif {motif_name} of {compare_to}...")

    calculator2 = CA1MotifCalculator(target,compare_to, CM)
    num_motifs2 = calculator2.count_motifs()  # proj samples not used for local computations

    target_motifs_perisomatic[motif_name] = num_motifs
    target_motifs_distal[motif_name] = num_motifs2
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]INFO:root:Running motif calculation for cylinder300 of motif -C of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (-C) within the given adj matrix: 7622836
# INFO:root:Running motif calculation for cylinder300 of motif -C of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (-C) within the given adj matrix: 26027701
#   6%|▋         | 1/16 [00:30<07:34, 30.28s/it]INFO:root:Running motif calculation for cylinder300 of motif -B of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (-B) within the given adj matrix: 5122637
# INFO:root:Running motif calculation for cylinder300 of motif -B of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (-B) within the given adj matrix: 12960445
#  12%|█▎        | 2/16 [01:00<07:01, 30.11s/it]INFO:root:Running motif calculation for cylinder300 of motif -A of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (-A) within the given adj matrix: 11394634
# INFO:root:Running motif calculation for cylinder300 of motif -A of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (-A) within the given adj matrix: 141943090
#  19%|█▉        | 3/16 [01:30<06:29, 29.94s/it]INFO:root:Running motif calculation for cylinder300 of motif A of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (A) within the given adj matrix: 3906726
# INFO:root:Running motif calculation for cylinder300 of motif A of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (A) within the given adj matrix: 5785330
#  25%|██▌       | 4/16 [01:59<05:57, 29.82s/it]INFO:root:Running motif calculation for cylinder300 of motif B of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (-A) within the given adj matrix: 1918518
# INFO:root:Running motif calculation for cylinder300 of motif B of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (-A) within the given adj matrix: 6215127
#  31%|███▏      | 5/16 [02:29<05:26, 29.70s/it]INFO:root:Running motif calculation for cylinder300 of motif C of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (C) within the given adj matrix: 5561192
# INFO:root:Running motif calculation for cylinder300 of motif C of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (C) within the given adj matrix: 10514586
#  38%|███▊      | 6/16 [02:58<04:56, 29.68s/it]INFO:root:Running motif calculation for cylinder300 of motif D of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (D) within the given adj matrix: 5374716
# INFO:root:Running motif calculation for cylinder300 of motif D of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (D) within the given adj matrix: 45830825
#  44%|████▍     | 7/16 [03:28<04:26, 29.65s/it]INFO:root:Running motif calculation for cylinder300 of motif E of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (E) within the given adj matrix: 5561192
# INFO:root:Running motif calculation for cylinder300 of motif E of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (E) within the given adj matrix: 10514586
#  50%|█████     | 8/16 [03:58<03:57, 29.67s/it]INFO:root:Running motif calculation for cylinder300 of motif F of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (F) within the given adj matrix: 4593513
# INFO:root:Running motif calculation for cylinder300 of motif F of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (F) within the given adj matrix: 61549504
#  56%|█████▋    | 9/16 [04:27<03:27, 29.64s/it]INFO:root:Running motif calculation for cylinder300 of motif G of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (G) within the given adj matrix: 741381
# INFO:root:Running motif calculation for cylinder300 of motif G of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (G) within the given adj matrix: 5590653
#  62%|██████▎   | 10/16 [04:57<02:57, 29.64s/it]INFO:root:Running motif calculation for cylinder300 of motif H of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (H) within the given adj matrix: 24440316
# INFO:root:Running motif calculation for cylinder300 of motif H of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (H) within the given adj matrix: 204873502
#  69%|██████▉   | 11/16 [05:26<02:28, 29.65s/it]INFO:root:Running motif calculation for cylinder300 of motif I of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (I) within the given adj matrix: 8253182
# INFO:root:Running motif calculation for cylinder300 of motif I of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (I) within the given adj matrix: 347607958
#  75%|███████▌  | 12/16 [05:56<01:58, 29.55s/it]INFO:root:Running motif calculation for cylinder300 of motif J of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (J) within the given adj matrix: 5905363
# INFO:root:Running motif calculation for cylinder300 of motif J of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (J) within the given adj matrix: 91201605
#  81%|████████▏ | 13/16 [06:25<01:28, 29.49s/it]INFO:root:Running motif calculation for cylinder300 of motif K of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (K) within the given adj matrix: 12459558
# INFO:root:Running motif calculation for cylinder300 of motif K of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (K) within the given adj matrix: 167054608
#  88%|████████▊ | 14/16 [06:54<00:58, 29.43s/it]INFO:root:Running motif calculation for cylinder300 of motif L of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (L) within the given adj matrix: 36252614
# INFO:root:Running motif calculation for cylinder300 of motif L of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (L) within the given adj matrix: 2111817843
#  94%|█████████▍| 15/16 [07:24<00:29, 29.37s/it]INFO:root:Running motif calculation for cylinder300 of motif M of ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH']...
# WARNING:root:check_mtypes: ['PeriSomatic_INH', 'PeriSomatic_INH', 'PeriSomatic_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (M) within the given adj matrix: 193627644
# INFO:root:Running motif calculation for cylinder300 of motif M of ['Distal_INH', 'Distal_INH', 'Distal_INH']...
# WARNING:root:check_mtypes: ['Distal_INH', 'Distal_INH', 'Distal_INH'] not found in mtypes: ['SLM_PPA', 'SO_BP', 'SO_BS', 'SO_OLM', 'SO_Tri', 'SP_AA', 'SP_BS', 'SP_CCKBC', 'SP_Ivy', 'SP_PC', 'SP_PVBC', 'SR_SCA']. Fetching from circuit targets
# INFO:root:Total instances of given motif (M) within the given adj matrix: 74607217494
# 100%|██████████| 16/16 [07:53<00:00, 29.60s/it]

# %%
df1 = pd.DataFrame.from_dict(target_motifs_perisomatic, orient='index',columns=[f'{target}_perisomatic'])
df2 = pd.DataFrame.from_dict(target_motifs_distal, orient='index',columns=[f'{target}_distal'])

df_peridistal = pd.concat([df1,df2],axis=1)
df_peridistal['ratio'] = df_peridistal[f'{target}_perisomatic']/df_peridistal[f'{target}_distal']
df_peridistal.to_csv(f'{save_dir}/{target}_triplet_ratios_peridistal.csv')

# %%
chosen_df = df_peridistal.ratio[3:]
chosen_df.plot(figsize=(10,5),title=f'{target} motif ratio')
# plot all xticklabels
plt.xticks(np.arange(len(df_peridistal)-3), df_peridistal.index[3:])
# horizontal line at y=1
plt.axhline(y=1, color='r', linestyle='-')
plt.ylabel('Ratio')
plt.savefig(f'{save_dir}/{target}_triplet_ratios_peridistal.png',dpi=300)
plt.show()

chosen_df.plot(figsize=(10,5),title=f'{target} motif ratio')
# plot all xticklabels
plt.xticks(np.arange(len(df_peridistal)-3), df_peridistal.index[3:])
# horizontal line at y=1
plt.yscale('log')
plt.axhline(y=1, color='r', linestyle='-')
plt.ylabel('Ratio')
plt.savefig(f'{save_dir}/{target}_triplet_ratios_peridistal_log.png',dpi=300)
plt.show()

# %% [markdown]
# # Combined figure 7D

# %%
df_ei = pd.read_csv(f'{save_dir}/{target}_triplet_ratios_EI.csv',index_col=0)
df_peridistal = pd.read_csv(f'{save_dir}/{target}_triplet_ratios_peridistal.csv',index_col=0)

# %%
chosen_df1 = df_ei.ratio[3:]
# chosen_df1.plot(figsize=(10,5),title=f'{target} motif ratio')
# add black triangles and blue lines connecting for every point in the plot and lines
chosen_df1.plot(style='^-',ms=10,figsize=(10,5))

chosen_df2= df_peridistal.ratio[3:]
chosen_df2.plot(style='o-r',ms=10,figsize=(10,5))


# plot all xticklabels
plt.xticks(np.arange(len(df_peridistal)-3), df_peridistal.index[3:])
# horizontal line at y=1
plt.axhline(y=1, color='k', linestyle='-')
plt.ylabel('Ratio')
plt.legend(['CA1 Pyr:Int','CA1 PST:Other'])
plt.savefig(f'{save_dir}/{target}_Rees2016_Fig7D.png',dpi=300)
plt.show()
